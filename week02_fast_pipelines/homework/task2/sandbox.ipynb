# %%
import torch
import run_epoch
import importlib
importlib.reload(run_epoch)

from run_epoch import get_gpt2_model, run_epoch, DataMode

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

model = get_gpt2_model()

# %% [markdown]
# # Brain

# %%
run_epoch(DataMode.BRAIN, "data/wikitext-103-raw-v1", model, device)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (645 > 512). Running this sequence through the model will result in indexing errors
# Running epoch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 469/469 [01:16<00:00,  6.13it/s]
# INFO:run_epoch:Mean latency: 0.15286648568922076
# INFO:run_epoch:Median latency: 0.1531034167855978
# INFO:run_epoch:Min latency: 0.11008495464920998
# INFO:run_epoch:Max latency: 0.1550370678305626

# %% [markdown]
# # BigBrain

# %%
run_epoch(DataMode.BIG_BRAIN, "data/wikitext-103-raw-v1", model, device)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (645 > 512). Running this sequence through the model will result in indexing errors
# Running epoch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 469/469 [00:50<00:00,  9.30it/s]
# INFO:run_epoch:Mean latency: 0.10170568172530882
# INFO:run_epoch:Median latency: 0.09940181113779545
# INFO:run_epoch:Min latency: 0.07376153022050858
# INFO:run_epoch:Max latency: 0.15147336944937706

# %% [markdown]
# # UltraBigBrain

# %%
run_epoch(DataMode.ULTRA_BIG_BRAIN, "data/wikitext-103-raw-v1", model, device, k_value=1)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (645 > 512). Running this sequence through the model will result in indexing errors
# Running epoch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 640/640 [00:23<00:00, 27.00it/s]
# INFO:run_epoch:Mean latency: 0.03554907167169053
# INFO:run_epoch:Median latency: 0.0416388213634491
# INFO:run_epoch:Min latency: 0.0009025484323501587
# INFO:run_epoch:Max latency: 0.08068215101957321

# %%
run_epoch(DataMode.ULTRA_BIG_BRAIN, "data/wikitext-103-raw-v1", model, device, k_value=5)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (645 > 512). Running this sequence through the model will result in indexing errors
# Running epoch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 528/528 [00:20<00:00, 25.85it/s]
# INFO:run_epoch:Mean latency: 0.03708551614678841
# INFO:run_epoch:Median latency: 0.04752003774046898
# INFO:run_epoch:Min latency: 0.0014977194368839264
# INFO:run_epoch:Max latency: 0.09232552349567413

# %%
run_epoch(DataMode.ULTRA_BIG_BRAIN, "data/wikitext-103-raw-v1", model, device, k_value=10)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (645 > 512). Running this sequence through the model will result in indexing errors
# Running epoch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 502/502 [00:19<00:00, 25.14it/s]
# INFO:run_epoch:Mean latency: 0.03796539525360888
# INFO:run_epoch:Median latency: 0.04828472062945366
# INFO:run_epoch:Min latency: 0.0017726458609104156
# INFO:run_epoch:Max latency: 0.09906917065382004

# %%
run_epoch(DataMode.ULTRA_BIG_BRAIN, "data/wikitext-103-raw-v1", model, device, k_value=50)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (645 > 512). Running this sequence through the model will result in indexing errors
# Running epoch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 475/475 [00:21<00:00, 21.92it/s]
# INFO:run_epoch:Mean latency: 0.04341444278809618
# INFO:run_epoch:Median latency: 0.05213938467204571
# INFO:run_epoch:Min latency: 0.0072590745985507965
# INFO:run_epoch:Max latency: 0.11706149205565453

# %%
run_epoch(DataMode.ULTRA_BIG_BRAIN, "data/wikitext-103-raw-v1", model, device, k_value=640)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (645 > 512). Running this sequence through the model will result in indexing errors
# Running epoch: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 469/469 [00:49<00:00,  9.42it/s]
# INFO:run_epoch:Mean latency: 0.10063289257633531
# INFO:run_epoch:Median latency: 0.0981900691986084
# INFO:run_epoch:Min latency: 0.06276950612664223
# INFO:run_epoch:Max latency: 0.1496952548623085

# %% [markdown]
# Как видно есть тренд: чем меньше k, тем быстрее исполняется forward. Но это и понятно, потому что при малых k, у нас меньше разница длины
# между самой длинной и самой короткой последовательностью в батче, поэтому меньше pad токенов => меньше лишнего компьюта

# %% [markdown]
# Кроме того, при k=640 как и ожидалось получили такие же метрики, как в BigBrain

# %% [markdown]
# # UltraDuperBigBrain
