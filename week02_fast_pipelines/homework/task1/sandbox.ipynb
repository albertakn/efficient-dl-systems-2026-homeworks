# %%
from torch import amp
from train import train, CustomStaticGradScaler, CustomDynamicGradScaler

# %%
train(scaler=amp.GradScaler())
# Out:
# ...
# Loss: 0.5845 Accuracy: 99.0309: 100%|████████████████████████████████████████████████████████████| 40/40 [00:25<00:00,  1.58it/s]

# %%
train(scaler=CustomStaticGradScaler())
# Out:
# ...
# Loss: 0.5849 Accuracy: 98.8676: 100%|████████████████████████████████████████████████████████████| 40/40 [00:25<00:00,  1.58it/s]

# %%
train(scaler=CustomDynamicGradScaler())
# Out:
# ...
# Loss: 0.5837 Accuracy: 98.7428: 100%|████████████████████████████████████████████████████████████| 40/40 [00:25<00:00,  1.56it/s]
